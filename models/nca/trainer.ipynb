# %%
from trainNca import TrainNca
from simulator import NCARunner, configure_nca
from AgentTorch.helpers import read_config
import argparse
# Out:
# /Users/shashankkumar/anaconda3/envs/torch38/lib/python3.8/site-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(

# %%
config_file = "/Users/shashankkumar/Documents/AgentTorch/models/nca/config.yaml"

config, registry = configure_nca(config_file)
runner = NCARunner(read_config('/Users/shashankkumar/Documents/AgentTorch-original/AgentTorch/models/nca/config_nca.yaml'), registry)
runner.init()
trainer = TrainNca(runner=runner)
trainer.train()
# Out:
# step_n: 51  loss: 40.302268981933594  lr: 0.0019896264758540935
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/shashankkumar/Documents/AgentTorch-original/AgentTorch/models/nca/trainer_test.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell:/Users/shashankkumar/Documents/AgentTorch-original/AgentTorch/models/nca/trainer_test.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> runner.init()
#       <a href='vscode-notebook-cell:/Users/shashankkumar/Documents/AgentTorch-original/AgentTorch/models/nca/trainer_test.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> trainer = TrainIsoNca(runner=runner)
# ----> <a href='vscode-notebook-cell:/Users/shashankkumar/Documents/AgentTorch-original/AgentTorch/models/nca/trainer_test.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> trainer.train()
#
# File ~/Documents/AgentTorch-original/AgentTorch/models/nca/trainer_nca.py:86, in TrainIsoNca.train(self)
#      83 self.runner.reset()
#      84 self.opt.zero_grad()
# ---> 86 self.runner.step(step_n)  # its is sampled randomly right now
#      88 outputs = self.runner.state_trajectory[-1][:step_n+1]
#      89 list_outputs = [outputs[i]['agents']['automata']['cell_state'] for i in range(step_n+1)]
#
# File ~/Documents/AgentTorch-original/AgentTorch/AgentTorch/runner.py:83, in Runner.step(self, num_steps)
#      80 self.trajectory["observations"][-1][-1].append(observation_profile)
#      81 self.trajectory["actions"][-1][-1].append(action_profile)
# ---> 83 next_state = self.controller.progress(self.state, action_profile, self.initializer.transition_function)
#      84 self.state = next_state
#      86 self.state_trajectory[-1].append(self.state)
#
# File ~/Documents/AgentTorch-original/AgentTorch/AgentTorch/controller.py:39, in Controller.progress(self, state, action, transition_function)
#      38 def progress(self, state, action, transition_function):
# ---> 39     next_state = copy_module(state)
#      41     substep = state['current_substep']
#      42     next_substep = (int(substep) + 1)%self.config["simulation_metadata"]["num_substeps_per_step"]
#
# File ~/Documents/AgentTorch-original/AgentTorch/AgentTorch/helpers/general.py:37, in copy_module(dict_to_copy)
#      35     copied_dict[key] = torch.clone(value)
#      36 elif isinstance(value, dict):
# ---> 37     copied_dict[key] = copy_module(value)
#      38 elif not torch.is_tensor(value):
#      39     copied_dict[key] = copy.deepcopy(value)
#
# File ~/Documents/AgentTorch-original/AgentTorch/AgentTorch/helpers/general.py:37, in copy_module(dict_to_copy)
#      35     copied_dict[key] = torch.clone(value)
#      36 elif isinstance(value, dict):
# ---> 37     copied_dict[key] = copy_module(value)
#      38 elif not torch.is_tensor(value):
#      39     copied_dict[key] = copy.deepcopy(value)
#
# File ~/Documents/AgentTorch-original/AgentTorch/AgentTorch/helpers/general.py:37, in copy_module(dict_to_copy)
#      35     copied_dict[key] = torch.clone(value)
#      36 elif isinstance(value, dict):
# ---> 37     copied_dict[key] = copy_module(value)
#      38 elif not torch.is_tensor(value):
#      39     copied_dict[key] = copy.deepcopy(value)
#
# File ~/Documents/AgentTorch-original/AgentTorch/AgentTorch/helpers/general.py:39, in copy_module(dict_to_copy)
#      37     copied_dict[key] = copy_module(value)
#      38 elif not torch.is_tensor(value):
# ---> 39     copied_dict[key] = copy.deepcopy(value)
#      40 else:
#      41     raise TypeError("Type error.. ", type(value))
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~/anaconda3/envs/torch38/lib/python3.8/copy.py:144, in deepcopy(x, memo, _nil)
#     140     return y
#     142 cls = type(x)
# --> 144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
#     146     y = copier(x, memo)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
